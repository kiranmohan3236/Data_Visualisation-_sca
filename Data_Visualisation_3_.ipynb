# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranmohan3236/Data_Visualisation-_sca/blob/main/Data_Visualisation_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/vgsales.csv
# 100% 2.04M/2.04M [00:00<00:00, 28.0MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_gen = data['Genre'].value_counts().index[:3]
top3_plat = data['Platform'].value_counts().index[:3]

# %%
top3_pub
# Out:
# Index(['Electronic Arts', 'Activision', 'Namco Bandai Games'], dtype='object')

# %%
data["Publisher"].isin(top3_pub)
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 16647    False
# 16648    False
# 16649    False
# 16650    False
# 16651     True
# Name: Publisher, Length: 16652, dtype: bool

# %%
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
#How can we visualize the correlation between NA and EU,

# %%
sns.scatterplot(x='NA_Sales',y='EU_Sales',data =top3_data )
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x='NA_Sales', y='EU_Sales',hue='Publisher' ,data=top3_data)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('NA Sales',fontsize=15)
plt.ylabel('EU Sales',fontsize=15)
plt.title('NA vs EU, per Genre', fontsize=15)
plt.show()

# %% [markdown]
# Inferences:
#
# If we see this plot, we can notice now that Namco has lower sales correlation, while Activision has a concentrated positive correlation EA also has positive correlation, but it's more spread compared to Activision

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x='NA_Sales', y='EU_Sales',hue='Genre' ,data=top3_data)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('NA Sales',fontsize=15)
plt.ylabel('EU Sales',fontsize=15)
plt.title('NA vs EU, per Genre', fontsize=15)
plt.show()

# %%
# how will you visualize Global Sales for each publisher,

# %%
sns.barplot(x="Publisher",y="Global_Sales",data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.boxplot(x="Publisher",y="Global_Sales",data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.boxplot(x="Publisher",y="Global_Sales",hue='Genre',data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
#Observations:
#Namco has lower median sales in every Genre as compared to all publishers
#EA is dominating in Sports
# Namco: Action
# Activision: Misc
# EA: Sports

# %%
#how does rank affect the correlation between NA and EU Sales?#

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
sns.scatterplot(x='NA_Sales',y='EU_Sales',data=top3_data,size=data['Rank'],sizes = (1,200))
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
#Now interestingly, we can notice that higher ranking games are actually on the lower scale of sales, while lower ranking games are high on the sales side

# %%
plt.figure(figsize=(17,10))

sns.scatterplot(x='NA_Sales',y='EU_Sales',data=top3_data,size=data['Rank'],sizes = (1,50))
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
plt.figure(figsize=(27,15))

sns.jointplot(x='NA_Sales',y='EU_Sales',data=top3_data,color='red')

# %%
sns.histplot(top3_data['EU_Sales'])
# Out:
# <Axes: xlabel='EU_Sales', ylabel='Count'>

# %%
sns.histplot(top3_data['NA_Sales'])
# Out:
# <Axes: xlabel='NA_Sales', ylabel='Count'>

# %%
plt.hist(top3_data['EU_Sales'],color='blue')
sns.histplot(top3_data['EU_Sales'],color='orange')
plt.show()

# %%
sns.kdeplot(top3_data['NA_Sales'])
# Out:
# <Axes: xlabel='NA_Sales', ylabel='Density'>

# %%
sns.jointplot(x='NA_Sales',y='EU_Sales',hue='Genre',data=top3_data)

# %%
sns.pairplot(data=top3_data)

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
sns.pairplot(data=top3_data,hue='Genre')

# %%
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
top3_data.corr() #correlation (-1  to +1)
# Out:
# <ipython-input-122-c78d7a78d920>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   top3_data.corr()
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.328705 -0.873726 -0.735711  0.115459    -0.857567
# Year          0.328705  1.000000 -0.354256 -0.178026  0.055864    -0.239876
# NA_Sales     -0.873726 -0.354256  1.000000  0.617483 -0.233315     0.794353
# EU_Sales     -0.735711 -0.178026  0.617483  1.000000 -0.208249     0.771105
# JP_Sales      0.115459  0.055864 -0.233315 -0.208249  1.000000    -0.355825
# Other_Sales  -0.857567 -0.239876  0.794353  0.771105 -0.355825     1.000000
# Global_Sales -0.911721 -0.280351  0.856300  0.864147 -0.014193     0.878816
#
#               Global_Sales
# Rank             -0.911721
# Year             -0.280351
# ...

# %%
sns.heatmap(top3_data.corr())
# Out:
# <ipython-input-123-4ebbdee39bcf>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(top3_data.corr())
# <Axes: >

# %%
sns.heatmap(top3_data.corr(),annot=True)
# Out:
# <ipython-input-124-18ffa5a7edf9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(top3_data.corr(),annot=True)
# <Axes: >

# %%
sns.heatmap(top3_data.corr(),annot=True,cmap='Blues')
# Out:
# <ipython-input-125-79e343e29c53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(top3_data.corr(),annot=True,cmap='Blues')
# <Axes: >

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %%
sns.heatmap(top3_data.corr(),annot=True,cmap='PuBuGn')
# Out:
# <ipython-input-127-7e0f6b7b89a3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(top3_data.corr(),annot=True,cmap='PuBuGn')
# <Axes: >

# %%
sns.heatmap(top3_data.corr(), cmap= "coolwarm", annot=True)
plt.show()
# Out:
# <ipython-input-128-72b457990d68>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(top3_data.corr(), cmap= "coolwarm", annot=True)

# %%
# !wget https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Out:
# --2024-01-01 17:32:28--  https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0.01s
#
# 2024-01-01 17:32:28 (5.11 MB/s) - ‘titanic.csv’ saved [60302/60302]

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Jack present in this dataset?

# %%
df.loc[df['Name'].isin(['Jack'])] #will give you wrong
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.loc[df['Name'].str.contains("Harris")] #the right way
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 62            63         0       1
# 219          220         0       2
# 230          231         1       1
# 263          264         0       1
# 570          571         1       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 62                    Harris, Mr. Henry Birkhardt    male  45.0      1      0
# 219                            Harris, Mr. Walter    male  30.0      0      0
# 230  Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1      0
# 263                         Harrison, Mr. William    male  40.0      0      0
# 570                            Harris, Mr. George    male  62.0      0      0
#
#           Ticket    Fare Cabin Embarked
# 0      A/5 21171   7.250   NaN        S
# 62         36973  83.475   C83        S
# 219    W/C 14208  10.500   NaN        S
# ...

# %%
df.loc[df['Name'].str.contains("Jack")] #now checking for "Jack"
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 766          767         0       1  Brewe, Dr. Arthur Jackson  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 766      0      0  112379  39.6   NaN        C

# %%
#Question: What is the distribution of passenger ages on the Titanic?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'].dropna(), bins=30, kde=True, color='skyblue')
plt.title('Distribution of Ages Among Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#link for the below was given at 1.52 Time in Vedio

# %%
#!wget https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %%
#Question: What is the distribution of passenger ages on the Titanic?
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
# df = pd.read_csv('titanic.csv')

# Univariate analysis - Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'].dropna(), bins=30, kde=True, color='skyblue')
plt.title('Distribution of Ages Among Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Question: How is the gender distribution among Titanic passengers?
# Univariate analysis - Gender distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='Sex', data=df, palette='Set2')
plt.title('Gender Distribution Among Passengers')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#Question: What is the distribution of passenger classes (Pclass) on the Titanic?
# Univariate analysis - Passenger class distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='Pclass', data=df, palette='pastel')
plt.title('Distribution of Passenger Classes')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %%
#Bivariate Analysis: Question: How does the survival rate vary with passenger class?

# %%
# Bivariate analysis - Survival rate vs. Passenger Class
plt.figure(figsize=(10, 6))
sns.countplot(x='Pclass', hue='Survived', data=df, palette='pastel')
plt.title('Survival Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
Question: Is there a correlation between age and fare paid by passengers?
# Bivariate analysis - Correlation between Age and Fare
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Fare', data=df, color='coral')
plt.title('Correlation between Age and Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
Question: How does the survival rate vary based on gender?
# Bivariate analysis - Survival rate vs. Gender
plt.figure(figsize=(8, 5))
sns.countplot(x='Sex', hue='Survived', data=df, palette='Set2')
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
#Multivariate Analysis: Question: How does passenger age, fare, and class contribute to the survival status?

# %%
# Multivariate analysis - Age, Fare, and Survival status
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df, palette='coolwarm', size='Pclass', sizes=(10, 200))
scatter.set_title('Age, Fare, and Survival Status by Passenger Class')
plt.show()

# %%
Question: What is the relationship between age, fare, and the number of siblings/spouses (SibSp)?
# Multivariate analysis - Age, Fare, and Siblings/Spouses
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(x='Age', y='Fare', hue='SibSp', data=df, palette='viridis', size='SibSp', sizes=(10, 200))
scatter.set_title('Age, Fare, and Siblings/Spouses')
plt.show()

# %%
Question: How does passenger age, fare, and gender contribute to the survival status?
# Multivariate analysis - Age, Fare, and Survival status by Gender
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df, style='Sex', palette='coolwarm', markers=['o', 's'])
scatter.set_title('Age, Fare, and Survival Status by Gender')
plt.show()

# %%
#only Questions
Question: What is the distribution of passenger ages on the Titanic?
Question: How is the gender distribution among Titanic passengers?
Question: What is the distribution of passenger classes (Pclass) on the Titanic?
Question: How does the survival rate vary with passenger class?
Question: Is there a correlation between age and fare paid by passengers?
Question: How does the survival rate vary based on gender?
Question: How does passenger age, fare, and class contribute to the survival status?
Question: What is the relationship between age, fare, and the number of siblings/spouses (SibSp)?
Question: How does passenger age, fare, and gender contribute to the survival status?
